# %% [markdown]
# # Import / Read_csv

# %%
import pandas as pd
import numpy as np

# %%
age18_1 = pd.read_csv('data/age18_1.csv', index_col = 0)
age18_1
# Out:
# C:\Users\User\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (44,127,291,312,328,409,528,543) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#               mod_d             id       ID_fam    year  region  town_t  \
# 0     b'2022.03.08'  b'A701020501'  b'A7010205'  2018.0     1.0     1.0
# 1     b'2022.03.08'  b'A701021301'  b'A7010213'  2018.0     1.0     1.0
# 2     b'2022.03.08'  b'A701021302'  b'A7010213'  2018.0     1.0     1.0
# 4     b'2022.03.08'  b'A701023303'  b'A7010233'  2018.0     1.0     1.0
# 5     b'2022.03.08'  b'A701023304'  b'A7010233'  2018.0     1.0     1.0
# ...             ...            ...          ...     ...     ...     ...
# 7917  b'2022.03.08'  b'R707025101'  b'R7070251'  2018.0     8.0     2.0
# 7918  b'2022.03.08'  b'R707025102'  b'R7070251'  2018.0     8.0     2.0
# ...

# %%
age18_2 = pd.read_csv('data/age18_2.csv', index_col = 0)
age18_2
# Out:
#                  id  DI1_pr  DI2_pr  DI3_pr  DI4_pr  DI5_pr  DM2_pr  DM3_pr  \
# 0     b'A701020501'     1.0     1.0     0.0     8.0     8.0     8.0     8.0
# 1     b'A701021301'     8.0     8.0     8.0     8.0     8.0     8.0     8.0
# 2     b'A701021302'     1.0     8.0     8.0     8.0     8.0     1.0     8.0
# 4     b'A701023303'     8.0     8.0     8.0     8.0     8.0     8.0     8.0
# 5     b'A701023304'     1.0     8.0     8.0     8.0     8.0     8.0     1.0
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# 7917  b'R707025101'     8.0     8.0     8.0     1.0     8.0     8.0     8.0
# 7918  b'R707025102'     8.0     8.0     8.0     8.0     8.0     1.0     8.0
# 7927  b'R707031101'     8.0     8.0     8.0     8.0     8.0     1.0     8.0
# 7983  b'R708028503'     8.0     1.0     8.0     8.0     8.0     1.0     8.0
# 7987  b'R708028902'     1.0     8.0     8.0     8.0     8.0     8.0     8.0
#
# ...

# %% [markdown]
# # 결측치 및 데이터 확인

# %% [markdown]
# ## age18_2 (pre_age18_2)

# %% [markdown]
# ### info

# %%
# age18_2
age18_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1653 entries, 0 to 7987
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      1653 non-null   object
#  1   DI1_pr  1608 non-null   float64
#  2   DI2_pr  1608 non-null   float64
#  3   DI3_pr  1608 non-null   float64
#  4   DI4_pr  1539 non-null   float64
#  5   DI5_pr  1608 non-null   float64
#  6   DM2_pr  1608 non-null   float64
#  7   DM3_pr  1608 non-null   float64
#  8   DM4_pr  1608 non-null   float64
#  9   DJ2_pr  1608 non-null   float64
#  10  DJ4_pr  1608 non-null   float64
#  11  DJ6_pr  1608 non-null   float64
#  12  DJ8_pr  1608 non-null   float64
#  13  DI6_pr  1608 non-null   float64
#  14  DF2_pr  1608 non-null   float64
#  15  DL1_pr  1608 non-null   float64
#  16  DE1_pr  1608 non-null   float64
#  17  DE2_pr  1608 non-null   float64
#  18  DH4_pr  1608 non-null   float64
#  19  DC1_pr  1608 non-null   float64
# ...

# %%
age18_2.isnull().sum()
# Out:
# id          0
# DI1_pr     45
# DI2_pr     45
# DI3_pr     45
# DI4_pr    114
# DI5_pr     45
# DM2_pr     45
# DM3_pr     45
# DM4_pr     45
# DJ2_pr     45
# DJ4_pr     45
# DJ6_pr     45
# DJ8_pr     45
# DI6_pr     45
# DF2_pr     45
# DL1_pr     45
# DE1_pr     45
# DE2_pr     45
# DH4_pr     45
# DC1_pr     45
# DC2_pr     45
# DC3_pr     45
# DC4_pr     45
# DC5_pr     45
# DC6_pr     45
# DC7_pr     45
# DK8_pr     45
# DK9_pr     45
# DK4_pr     45
# dtype: int64

# %%
age18_2_columns = age18_2.columns
age18_2_columns
# Out:
# Index(['id', 'DI1_pr', 'DI2_pr', 'DI3_pr', 'DI4_pr', 'DI5_pr', 'DM2_pr',
#        'DM3_pr', 'DM4_pr', 'DJ2_pr', 'DJ4_pr', 'DJ6_pr', 'DJ8_pr', 'DI6_pr',
#        'DF2_pr', 'DL1_pr', 'DE1_pr', 'DE2_pr', 'DH4_pr', 'DC1_pr', 'DC2_pr',
#        'DC3_pr', 'DC4_pr', 'DC5_pr', 'DC6_pr', 'DC7_pr', 'DK8_pr', 'DK9_pr',
#        'DK4_pr'],
#       dtype='object')

# %%
age18_2_column = age18_2_columns[1:29]
print(age18_2_column)
print(len(age18_2_columns))
print(len(age18_2_column))
# Out:
# Index(['DI1_pr', 'DI2_pr', 'DI3_pr', 'DI4_pr', 'DI5_pr', 'DM2_pr', 'DM3_pr',
#        'DM4_pr', 'DJ2_pr', 'DJ4_pr', 'DJ6_pr', 'DJ8_pr', 'DI6_pr', 'DF2_pr',
#        'DL1_pr', 'DE1_pr', 'DE2_pr', 'DH4_pr', 'DC1_pr', 'DC2_pr', 'DC3_pr',
#        'DC4_pr', 'DC5_pr', 'DC6_pr', 'DC7_pr', 'DK8_pr', 'DK9_pr', 'DK4_pr'],
#       dtype='object')
# 29
# 28

# %%
age18_2['DI1_pr'].unique()
# Out:
# array([ 1.,  8., nan,  0.])

# %%
# 0:10 , 10:20 , 20:28 나눠서 하나씩 살펴보기
age18_2_column[0:10]
# Out:
# Index(['DI1_pr', 'DI2_pr', 'DI3_pr', 'DI4_pr', 'DI5_pr', 'DM2_pr', 'DM3_pr',
#        'DM4_pr', 'DJ2_pr', 'DJ4_pr'],
#       dtype='object')

# %% [markdown]
# ### column 0:10

# %% [markdown]
# 0. DI1_pr 고혈압 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당 / 9 : 모름, 무응답
#
# 1. DI2_pr 이상지질혈증 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당 / 9 : 모름, 무응답
#
# 2. DI3_pr 뇌졸중 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당 / 9 : 모름, 무응답
#
# 3. DI4_pr 심근경색증 또는 협심증 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당
#
# 4. DI5_pr 심근경색증 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당 / 9 : 모름
#
# 5. DM2_pr 골관절염 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당 / 9 : 모름
#
# 6. DM3_pr 류마티스성 관절염 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당 / 9 : 모름
#
# 7. DM4_pr 골다공증 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당 / 9 : 모름
#
# 8. DJ2_pr 폐결핵 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당 / 9 : 모름
#
# 9. DJ4_pr 천식 현재 유병 여부
#   0 : 없음 / 1 : 있음
#   8 : 비해당 / 9 : 모름

# %%
for i in age18_2_column[0:10]:
    print('-----------------'+i+'------------------')
    print(age18_2[i].unique())
# Out:
# -----------------DI1_pr------------------
# [ 1.  8. nan  0.]
# -----------------DI2_pr------------------
# [ 1.  8. nan  0.  9.]
# -----------------DI3_pr------------------
# [ 0.  8.  1. nan  9.]
# -----------------DI4_pr------------------
# [ 8.  1. nan  0.]
# -----------------DI5_pr------------------
# [ 8. nan  9.  1.  0.]
# -----------------DM2_pr------------------
# [ 8.  1. nan  9.  0.]
# -----------------DM3_pr------------------
# [ 8.  1. nan  9.  0.]
# -----------------DM4_pr------------------
# [ 8.  1. nan  9.  0.]
# -----------------DJ2_pr------------------
# [ 8.  0. nan  9.  1.]
# -----------------DJ4_pr------------------
# [ 8.  0. nan  9.  1.]

# %%
# 원본 복사 (index리셋)
pre_age18_2 = age18_2.reset_index().drop(['index'], axis=1)
pre_age18_2
# Out:
#                  id  DI1_pr  DI2_pr  DI3_pr  DI4_pr  DI5_pr  DM2_pr  DM3_pr  \
# 0     b'A701020501'     1.0     1.0     0.0     8.0     8.0     8.0     8.0
# 1     b'A701021301'     8.0     8.0     8.0     8.0     8.0     8.0     8.0
# 2     b'A701021302'     1.0     8.0     8.0     8.0     8.0     1.0     8.0
# 3     b'A701023303'     8.0     8.0     8.0     8.0     8.0     8.0     8.0
# 4     b'A701023304'     1.0     8.0     8.0     8.0     8.0     8.0     1.0
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# 1648  b'R707025101'     8.0     8.0     8.0     1.0     8.0     8.0     8.0
# 1649  b'R707025102'     8.0     8.0     8.0     8.0     8.0     1.0     8.0
# 1650  b'R707031101'     8.0     8.0     8.0     8.0     8.0     1.0     8.0
# 1651  b'R708028503'     8.0     1.0     8.0     8.0     8.0     1.0     8.0
# 1652  b'R708028902'     1.0     8.0     8.0     8.0     8.0     8.0     8.0
#
# ...

# %% [markdown]
# 8, 9 제거

# %%
for i in age18_2_column[0:10]:
    col_index = list(pre_age18_2.columns).index(i)

    # 8 제거
    pre_age18_2_index = pre_age18_2[pre_age18_2[i] == 8][i].index

    for j in list(pre_age18_2_index):
        pre_age18_2.iloc[j,col_index] = np.nan
    
    # 9 제거
    pre_age18_2_index = pre_age18_2[pre_age18_2[i] == 9][i].index

    for j in list(pre_age18_2_index):
        pre_age18_2.iloc[j,col_index] = np.nan

pre_age18_2
# Out:
#                  id  DI1_pr  DI2_pr  DI3_pr  DI4_pr  DI5_pr  DM2_pr  DM3_pr  \
# 0     b'A701020501'     1.0     1.0     0.0     NaN     NaN     NaN     NaN
# 1     b'A701021301'     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     b'A701021302'     1.0     NaN     NaN     NaN     NaN     1.0     NaN
# 3     b'A701023303'     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     b'A701023304'     1.0     NaN     NaN     NaN     NaN     NaN     1.0
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# 1648  b'R707025101'     NaN     NaN     NaN     1.0     NaN     NaN     NaN
# 1649  b'R707025102'     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# 1650  b'R707031101'     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# 1651  b'R708028503'     NaN     1.0     NaN     NaN     NaN     1.0     NaN
# 1652  b'R708028902'     1.0     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
# 0~10 8, 9 제거 확인
for i in age18_2_column[0:10]:
    print('-----------------'+i+'------------------')
    print(pre_age18_2[i].unique())
# Out:
# -----------------DI1_pr------------------
# [ 1. nan  0.]
# -----------------DI2_pr------------------
# [ 1. nan  0.]
# -----------------DI3_pr------------------
# [ 0. nan  1.]
# -----------------DI4_pr------------------
# [nan  1.  0.]
# -----------------DI5_pr------------------
# [nan  1.  0.]
# -----------------DM2_pr------------------
# [nan  1.  0.]
# -----------------DM3_pr------------------
# [nan  1.  0.]
# -----------------DM4_pr------------------
# [nan  1.  0.]
# -----------------DJ2_pr------------------
# [nan  0.  1.]
# -----------------DJ4_pr------------------
# [nan  0.  1.]

# %% [markdown]
# ### column 10:20

# %% [markdown]
# 10. DJ6_pr 부비동염 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 11. DJ8_pr 알레르기비염 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 12. DI6_pr 협심증 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 13. DF2_pr 우울증 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 14. DL1_pr 아토피피부염 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 15. DE1_pr 당뇨병 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 16. DE2_pr 갑상선 질환 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 17. DH4_pr 중이염 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 18. DC1_pr 위암 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 19. DC2_pr 간암 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름

# %%
# 10:20 하나씩 살펴보기
age18_2_column[10:20]
# Out:
# Index(['DJ6_pr', 'DJ8_pr', 'DI6_pr', 'DF2_pr', 'DL1_pr', 'DE1_pr', 'DE2_pr',
#        'DH4_pr', 'DC1_pr', 'DC2_pr'],
#       dtype='object')

# %%
for i in age18_2_column[10:20]:
    print('-----------------'+i+'------------------')
    print(age18_2[i].unique())
# Out:
# -----------------DJ6_pr------------------
# [ 8.  0. nan  9.  1.]
# -----------------DJ8_pr------------------
# [ 8.  0.  1. nan  9.]
# -----------------DI6_pr------------------
# [ 8.  1. nan  9.  0.]
# -----------------DF2_pr------------------
# [ 8. nan  0.  1.  9.]
# -----------------DL1_pr------------------
# [ 8. nan  9.  1.  0.]
# -----------------DE1_pr------------------
# [ 8.  1. nan  0.  9.]
# -----------------DE2_pr------------------
# [ 8.  1. nan  9.  0.]
# -----------------DH4_pr------------------
# [ 8. nan  9.  0.  1.]
# -----------------DC1_pr------------------
# [ 8.  1. nan  9.  0.]
# -----------------DC2_pr------------------
# [ 8. nan  9.  1.  0.]

# %%
for i in age18_2_column[10:20]:
    col_index = list(pre_age18_2.columns).index(i)

    # 8 제거
    pre_age18_2_index = pre_age18_2[pre_age18_2[i] == 8][i].index

    for j in list(pre_age18_2_index):
        pre_age18_2.iloc[j,col_index] = np.nan
    
    # 9 제거
    pre_age18_2_index = pre_age18_2[pre_age18_2[i] == 9][i].index

    for j in list(pre_age18_2_index):
        pre_age18_2.iloc[j,col_index] = np.nan

pre_age18_2
# Out:
#                  id  DI1_pr  DI2_pr  DI3_pr  DI4_pr  DI5_pr  DM2_pr  DM3_pr  \
# 0     b'A701020501'     1.0     1.0     0.0     NaN     NaN     NaN     NaN
# 1     b'A701021301'     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     b'A701021302'     1.0     NaN     NaN     NaN     NaN     1.0     NaN
# 3     b'A701023303'     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     b'A701023304'     1.0     NaN     NaN     NaN     NaN     NaN     1.0
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# 1648  b'R707025101'     NaN     NaN     NaN     1.0     NaN     NaN     NaN
# 1649  b'R707025102'     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# 1650  b'R707031101'     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# 1651  b'R708028503'     NaN     1.0     NaN     NaN     NaN     1.0     NaN
# 1652  b'R708028902'     1.0     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
# 확인
for i in age18_2_column[10:20]:
    print('-----------------'+i+'------------------')
    print(pre_age18_2[i].unique())
# Out:
# -----------------DJ6_pr------------------
# [nan  0.  1.]
# -----------------DJ8_pr------------------
# [nan  0.  1.]
# -----------------DI6_pr------------------
# [nan  1.  0.]
# -----------------DF2_pr------------------
# [nan  0.  1.]
# -----------------DL1_pr------------------
# [nan  1.  0.]
# -----------------DE1_pr------------------
# [nan  1.  0.]
# -----------------DE2_pr------------------
# [nan  1.  0.]
# -----------------DH4_pr------------------
# [nan  0.  1.]
# -----------------DC1_pr------------------
# [nan  1.  0.]
# -----------------DC2_pr------------------
# [nan  1.  0.]

# %% [markdown]
# ### column 20:28

# %% [markdown]
# 20. DC3_pr 대장암 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 21. DC4_pr 유방암 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 22. DC5_pr 자궁경부암 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 23. DC6_pr 폐암 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 24. DC7_pr 갑상선암 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 25. DK8_pr B형간염 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 26. DK9_pr C형간염 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 27. DK4_pr 간경변증 현재 유병 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름

# %%
# 20:28 하나씩 살펴보기
age18_2_column[20:]
# Out:
# Index(['DC3_pr', 'DC4_pr', 'DC5_pr', 'DC6_pr', 'DC7_pr', 'DK8_pr', 'DK9_pr',
#        'DK4_pr'],
#       dtype='object')

# %%
for i in age18_2_column[20:28]:
    print('-----------------'+i+'------------------')
    print(age18_2[i].unique())
# Out:
# -----------------DC3_pr------------------
# [ 8.  0. nan  9.  1.]
# -----------------DC4_pr------------------
# [ 8.  1. nan  9.  0.]
# -----------------DC5_pr------------------
# [ 8. nan  9.  0.]
# -----------------DC6_pr------------------
# [ 8. nan  9.  1.  0.]
# -----------------DC7_pr------------------
# [ 8. nan  9.  0.  1.]
# -----------------DK8_pr------------------
# [ 8.  1. nan  9.  0.]
# -----------------DK9_pr------------------
# [ 8.  1. nan  9.  0.]
# -----------------DK4_pr------------------
# [ 8.  1. nan  9.  0.]

# %%
for i in age18_2_column[20:28]:
    col_index = list(pre_age18_2.columns).index(i)

    # 8 제거
    pre_age18_2_index = pre_age18_2[pre_age18_2[i] == 8][i].index

    for j in list(pre_age18_2_index):
        pre_age18_2.iloc[j,col_index] = np.nan
    
    # 9 제거
    pre_age18_2_index = pre_age18_2[pre_age18_2[i] == 9][i].index

    for j in list(pre_age18_2_index):
        pre_age18_2.iloc[j,col_index] = np.nan

pre_age18_2
# Out:
#                  id  DI1_pr  DI2_pr  DI3_pr  DI4_pr  DI5_pr  DM2_pr  DM3_pr  \
# 0     b'A701020501'     1.0     1.0     0.0     NaN     NaN     NaN     NaN
# 1     b'A701021301'     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     b'A701021302'     1.0     NaN     NaN     NaN     NaN     1.0     NaN
# 3     b'A701023303'     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     b'A701023304'     1.0     NaN     NaN     NaN     NaN     NaN     1.0
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# 1648  b'R707025101'     NaN     NaN     NaN     1.0     NaN     NaN     NaN
# 1649  b'R707025102'     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# 1650  b'R707031101'     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# 1651  b'R708028503'     NaN     1.0     NaN     NaN     NaN     1.0     NaN
# 1652  b'R708028902'     1.0     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
# 확인
for i in age18_2_column[20:28]:
    print('-----------------'+i+'------------------')
    print(pre_age18_2[i].unique())
# Out:
# -----------------DC3_pr------------------
# [nan  0.  1.]
# -----------------DC4_pr------------------
# [nan  1.  0.]
# -----------------DC5_pr------------------
# [nan  0.]
# -----------------DC6_pr------------------
# [nan  1.  0.]
# -----------------DC7_pr------------------
# [nan  0.  1.]
# -----------------DK8_pr------------------
# [nan  1.  0.]
# -----------------DK9_pr------------------
# [nan  1.  0.]
# -----------------DK4_pr------------------
# [nan  1.  0.]

# %% [markdown]
# ## age18_1 (pre_age18_1)

# %% [markdown]
# ### info

# %%
# 원본 확인
age18_1
# Out:
#               mod_d             id       ID_fam    year  region  town_t  \
# 0     b'2022.03.08'  b'A701020501'  b'A7010205'  2018.0     1.0     1.0
# 1     b'2022.03.08'  b'A701021301'  b'A7010213'  2018.0     1.0     1.0
# 2     b'2022.03.08'  b'A701021302'  b'A7010213'  2018.0     1.0     1.0
# 4     b'2022.03.08'  b'A701023303'  b'A7010233'  2018.0     1.0     1.0
# 5     b'2022.03.08'  b'A701023304'  b'A7010233'  2018.0     1.0     1.0
# ...             ...            ...          ...     ...     ...     ...
# 7917  b'2022.03.08'  b'R707025101'  b'R7070251'  2018.0     8.0     2.0
# 7918  b'2022.03.08'  b'R707025102'  b'R7070251'  2018.0     8.0     2.0
# 7927  b'2022.03.08'  b'R707031101'  b'R7070311'  2018.0     8.0     2.0
# 7983  b'2022.03.08'  b'R708028503'  b'R7080285'  2018.0     8.0     1.0
# 7987  b'2022.03.08'  b'R708028902'  b'R7080289'  2018.0     8.0     1.0
#
#       apt_t      psu  sex   age  ...  HEI_TVEG   HEI_VEG  HEI_PROTF  \
# ...

# %%
# 원본 복사 (index리셋)
pre_age18_1 = age18_1.reset_index().drop(['index'], axis=1)
pre_age18_1
# Out:
#               mod_d             id       ID_fam    year  region  town_t  \
# 0     b'2022.03.08'  b'A701020501'  b'A7010205'  2018.0     1.0     1.0
# 1     b'2022.03.08'  b'A701021301'  b'A7010213'  2018.0     1.0     1.0
# 2     b'2022.03.08'  b'A701021302'  b'A7010213'  2018.0     1.0     1.0
# 3     b'2022.03.08'  b'A701023303'  b'A7010233'  2018.0     1.0     1.0
# 4     b'2022.03.08'  b'A701023304'  b'A7010233'  2018.0     1.0     1.0
# ...             ...            ...          ...     ...     ...     ...
# 1648  b'2022.03.08'  b'R707025101'  b'R7070251'  2018.0     8.0     2.0
# 1649  b'2022.03.08'  b'R707025102'  b'R7070251'  2018.0     8.0     2.0
# 1650  b'2022.03.08'  b'R707031101'  b'R7070311'  2018.0     8.0     2.0
# 1651  b'2022.03.08'  b'R708028503'  b'R7080285'  2018.0     8.0     1.0
# 1652  b'2022.03.08'  b'R708028902'  b'R7080289'  2018.0     8.0     1.0
#
#       apt_t      psu  sex   age  ...  HEI_TVEG   HEI_VEG  HEI_PROTF  \
# ...

# %%
pre_age18_1_column = pre_age18_1.columns
age18_1_column = pre_age18_1_column
age18_1_column
# Out:
# Index(['mod_d', 'id', 'ID_fam', 'year', 'region', 'town_t', 'apt_t', 'psu',
#        'sex', 'age',
#        ...
#        'HEI_TVEG', 'HEI_VEG', 'HEI_PROTF', 'HEI_DAIRY', 'HEI_SFA', 'HEI_NA',
#        'HEI_SWEET', 'HEI_CHO', 'HEI_FAT', 'HEI_EN'],
#       dtype='object', length=758)

# %% [markdown]
# ### column 0:40

# %% [markdown]
# 0. mod_d 최종 DB 수정일
#     text
#
# 1. id 개인 아이디
#     text
#
# 2. ID_fam 가구 아이디
#     text
#
# 3. year 조사연도
#     2018
#
# 4. region 17개 시도
#     1 서울 ~ 17 제주
#
# 5. town_t 동/읍면 구분
#     1 : 동 / 2 : 읍,면
#
# 6. apt_t 아파트 구분
#     1 : 일반 / 아파트
#
# 7. psu 조사구 번호
#     text
#
# 8. sex 성별
#     1 : 남자 / 2 : 여자
#
# 9. age 만나이
#     1~79 / 80 : 80세 이상

# %% [markdown]
# 10. age_month 월령 (만1~6세)
#     ~ 개월
#
# 11. incm 소득 4분위수(개인)
#     1 : 하 / 2 : 중하 / 3 : 중상 / 4 : 상
#
# 12. ho_incm 소득 4분위수(가구)
#     1 : 하 / 2 : 중하 / 3 : 중상 / 4 : 상
#
# 13. incm5 소득 5분위수(개인)
#     1 : 하 / 2 : 중하 / 3 : 중 / 4 : 중상 / 5 : 상
#
# 14. ho_incm5 소득 5분위수(가구)
#     1 : 하 / 2 : 중하 / 3 : 중 / 4 : 중상 / 5 : 상
#
# 15. edu 교육수준 재분류 코드
#     1 : 초졸이하 / 2 : 중졸 / 3 : 고졸 / 4 : 대졸이상
#
# 16. occp 직업재분류 및 실업/비경제활동 상태 코드
#     1~7 : 직업 코드 7:무직(주부,학생 등)
#
# 17. wt_hs 가구조사 가중치
#     설명 없음
#
# 18. wt_itvex 건강설문 - 검진조사 가중치
#     설명 없음
#
# 19. wt_pft 폐기능검사 가중치 (만 40세 이상)
#     설명없음

# %% [markdown]
# 20. wt_vt 비타민검사 가중치(만10세이상)
#
# 21. wt_nn NNAL검사 가중치(만6세이상)
#
# 22. wt_ntr 영양조사 가중치
#
# 23. wt_tot 건강설문-검진조사 & 영양조사 가중치
#
# 24. wt_pfnt 폐기능검사 & 중금속검사 가중치(만40세이상)
#
# 25. wt_pfvt 폐기능검사 & 비타민검사 가중치(만40세이상)
#
# 26. wt_pfvtnt 폐기능검사 & 비타민검사 & 영양조사 가중치(만40세이상)
#
# 27. wt_vtnt 비타민검사 & 영양조사 가중치(만10세이상)
#
# 28. wt_nnnt NNAL검사 & 영양조사 가중치(만6세이상)
#
# 29. kstrata 분산추정 층

# %% [markdown]
# 30. cfam 가구원수
#     1~6 : 1 5명 / 6 : 6명 이상
#     9 : 모름
#
# 31. genertn 가구 세대구성코드
#     1~3 1세대 (1인/부부/기타)
#     4~6 2세대 (부부+미혼자녀/편부모+미혼자녀/기타)
#     7 3세대 이상
#     9 모름
#
# 32. allownc 기초생활수급 여부
#     10 : 경험있음 (과거 또는 현재)
#     20 : 없음
#     99 : 모름
#
# 33. house 주택소유여부
#     1 : 아니오 / 2 : 1채 / 3 : 2채이상
#     9 : 모름
#
# 34. live_t 주택형태(18년)
#     1 : 단독주택 / 2 : 아파트 / 3 : 연립주택 / 4 : 기타
#     9 : 모름
#
# 35. ainc_unit1 가구총소득 소득단위
#     1 : 연 / 2 : 월
#     9 : 모름
#
# 36. ainc_1 가구총소득 소득액
#     200 : 연 200 이하 / 17 : 월 17 이하
#     18000 : 연 1.8억 이상 / 1500 : 월 1500 이상
#     999999 : 모름
#
# 37. ainc 월평균 가구 총소득
#     17 : 월 17 이하 / 1500 : 월 1500 이상
#
# 38. marri_1 결혼여부
#     1 : 기혼 / 2 : 미혼
#     9 : 모름
#
# 39. marri_2 결혼상태
#     1~4 : 유배우자(동거/별거), 사별, 이혼
#     8 : 응답거부 / 9 : 모름 / 88 : 비해당 / 99 : 무응답

# %%
# 컬럼 보기
pre_age18_1_column[30:36]
# Out:
# Index(['cfam', 'genertn', 'allownc', 'house', 'live_t', 'ainc_unit1'], dtype='object')

# %%
# 각 컬럼 유니크 값
for i in pre_age18_1_column[30:36]:
    print('-----------------'+i+'------------------')
    print(pre_age18_1[i].unique())
# Out:
# -----------------cfam------------------
# [3. 2. 4. 1. 6. 5.]
# -----------------genertn------------------
# [6. 2. 3. 4. 7. 5. 1.]
# -----------------allownc------------------
# [20. 10. 99.]
# -----------------house------------------
# [2. 3. 1. 9.]
# -----------------live_t------------------
# [2. 1. 3. 4.]
# -----------------ainc_unit1------------------
# [2. 1. 9.]

# %%
# 30:36 9, 99 제거
# 값 제거
for i in age18_1_column[30:36]:
    col_index = list(pre_age18_1.columns).index(i)

    # 99 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 99][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan
    
    # 9 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 9][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan

pre_age18_1.iloc[:,30:36]
# Out:
#       cfam  genertn  allownc  house  live_t  ainc_unit1
# 0      3.0      6.0     20.0    2.0     2.0         2.0
# 1      2.0      2.0     20.0    3.0     2.0         2.0
# 2      2.0      2.0     20.0    3.0     2.0         2.0
# 3      2.0      3.0     20.0    1.0     2.0         1.0
# 4      2.0      3.0     20.0    1.0     2.0         1.0
# ...    ...      ...      ...    ...     ...         ...
# 1648   2.0      2.0     20.0    2.0     1.0         1.0
# 1649   2.0      2.0     20.0    2.0     1.0         1.0
# 1650   1.0      1.0     20.0    3.0     1.0         2.0
# 1651   6.0      7.0     20.0    2.0     2.0         1.0
# 1652   3.0      5.0     20.0    2.0     2.0         2.0
#
# [1653 rows x 6 columns]

# %%
# 확인
for i in pre_age18_1_column[30:36]:
    print('-----------------'+i+'------------------')
    print(pre_age18_1[i].unique())
# Out:
# -----------------cfam------------------
# [3. 2. 4. 1. 6. 5.]
# -----------------genertn------------------
# [6. 2. 3. 4. 7. 5. 1.]
# -----------------allownc------------------
# [20. 10. nan]
# -----------------house------------------
# [ 2.  3.  1. nan]
# -----------------live_t------------------
# [2. 1. 3. 4.]
# -----------------ainc_unit1------------------
# [ 2.  1. nan]

# %%
# 각 컬럼 유니크 값
for i in pre_age18_1_column[36:37]:
    print('-----------------'+i+'------------------')
    print(pre_age18_1[i].unique())
# Out:
# -----------------ainc_1------------------
# [8.00000e+01 1.50000e+03 9.08000e+02 1.80000e+04 1.00000e+04 9.99999e+05
#  5.40000e+02 4.00000e+02 1.07000e+02 9.00000e+01 2.21100e+03 5.00000e+02
#  1.50000e+02 1.78000e+02 8.30000e+01 2.50000e+02 1.57000e+02 2.60000e+02
#  7.20000e+03 1.33200e+03 4.70000e+01 9.70000e+01 3.77000e+02 6.50000e+01
#  4.35000e+02 1.80000e+02 1.00000e+02 9.36000e+02 1.97000e+02 3.00000e+02
#  1.00000e+03 2.00000e+02 6.00000e+03 1.40000e+02 5.10000e+02 3.50000e+02
#  8.51600e+03 2.13000e+02 7.50000e+02 4.40000e+02 1.33600e+04 8.90000e+02
#  6.00000e+02 2.16000e+03 5.00000e+03 7.50000e+01 8.40000e+01 2.28000e+02
#  8.60000e+01 7.70000e+01 2.09100e+03 4.71200e+03 4.50000e+02 1.60000e+02
#  8.35000e+02 6.20000e+01 4.78000e+02 8.07600e+03 5.38400e+03 4.50000e+03
#  2.36000e+02 4.80000e+03 4.42000e+02 1.70000e+04 2.16000e+02 8.00000e+02
#  4.30000e+01 6.80000e+01 5.17000e+02 9.32000e+02 7.00000e+01 6.00000e+01
# ...

# %%
# 36:37 (36) 999999 제거
# 값 제거
for i in age18_1_column[30:36]:
    col_index = list(pre_age18_1.columns).index(i)

    # 99 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 999999][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan


pre_age18_1.iloc[:,36:37]
# Out:
#       ainc_1
# 0       80.0
# 1     1500.0
# 2     1500.0
# 3      908.0
# 4      908.0
# ...      ...
# 1648  4520.0
# 1649  4520.0
# 1650    80.0
# 1651  8130.0
# 1652   110.0
#
# [1653 rows x 1 columns]

# %%
# 확인
for i in pre_age18_1_column[36:37]:
    print('-----------------'+i+'------------------')
    print(pre_age18_1[i].unique())
# Out:
# -----------------ainc_1------------------
# [8.00000e+01 1.50000e+03 9.08000e+02 1.80000e+04 1.00000e+04 9.99999e+05
#  5.40000e+02 4.00000e+02 1.07000e+02 9.00000e+01 2.21100e+03 5.00000e+02
#  1.50000e+02 1.78000e+02 8.30000e+01 2.50000e+02 1.57000e+02 2.60000e+02
#  7.20000e+03 1.33200e+03 4.70000e+01 9.70000e+01 3.77000e+02 6.50000e+01
#  4.35000e+02 1.80000e+02 1.00000e+02 9.36000e+02 1.97000e+02 3.00000e+02
#  1.00000e+03 2.00000e+02 6.00000e+03 1.40000e+02 5.10000e+02 3.50000e+02
#  8.51600e+03 2.13000e+02 7.50000e+02 4.40000e+02 1.33600e+04 8.90000e+02
#  6.00000e+02 2.16000e+03 5.00000e+03 7.50000e+01 8.40000e+01 2.28000e+02
#  8.60000e+01 7.70000e+01 2.09100e+03 4.71200e+03 4.50000e+02 1.60000e+02
#  8.35000e+02 6.20000e+01 4.78000e+02 8.07600e+03 5.38400e+03 4.50000e+03
#  2.36000e+02 4.80000e+03 4.42000e+02 1.70000e+04 2.16000e+02 8.00000e+02
#  4.30000e+01 6.80000e+01 5.17000e+02 9.32000e+02 7.00000e+01 6.00000e+01
# ...

# %%
# 각 컬럼 유니크 값
for i in pre_age18_1_column[ 37:40 ]:
    print('-----------------'+i+'------------------')
    print(pre_age18_1[i].unique())
# Out:
# -----------------ainc------------------
# [  80.         1500.           75.66666667  833.33333333           nan
#   540.          400.          107.           90.          184.25
#   500.          150.          178.           83.          250.
#   157.          260.          600.          111.           47.
#    97.          377.           65.          435.          180.
#   100.           78.          197.          300.         1000.
#   200.          140.          510.          350.          709.66666667
#   213.          750.          440.         1113.33333333  890.
#   416.66666667   75.           84.          228.           86.
#    77.          174.25        392.66666667  450.          160.
#    69.58333333   62.          478.          673.          448.66666667
#   375.          236.          442.         1416.66666667  216.
#   800.           43.           68.           43.08333333   77.66666667
#    70.           60.           68.33333333   42.91666667   50.
# ...

# %%
# 값 제거
for i in age18_1_column[ 38:40 ]:
    col_index = list(pre_age18_1.columns).index(i)

    # 8 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 8][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan
    
    # 9 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 9][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan
    
    # 88 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 88][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan
    
    # 99 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 99][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan

pre_age18_1.iloc[:,38:40]
# Out:
#       marri_1  marri_2
# 0         1.0      3.0
# 1         1.0      1.0
# 2         1.0      1.0
# 3         1.0      3.0
# 4         1.0      4.0
# ...       ...      ...
# 1648      1.0      1.0
# 1649      1.0      1.0
# 1650      1.0      3.0
# 1651      1.0      3.0
# 1652      1.0      3.0
#
# [1653 rows x 2 columns]

# %%
# 확인
for i in pre_age18_1_column[ 38:40 ]:
    print('-----------------'+i+'------------------')
    print(pre_age18_1[i].unique())
# Out:
# -----------------marri_1------------------
# [1. 2.]
# -----------------marri_2------------------
# [ 3.  1.  4. nan  2.]

# %% [markdown]
# ### column 40:50

# %% [markdown]
# 40. fam_rela 가구주와의 관계
#     1~10 : 본인 .. 10:비혈연
#     99 : 모름
#
# 41. tins 건강보험종류
#     10, 20 : 국민건강보험(지역/직장) / 30 : 의료급여
#     99 : 미가입, 모름, 무응답
#
# 42. npins 민간의료보험가입여부
#     1 : 예 / 2 : 아니오
#     9 : 모름
#
# 43. id_F 아버지 아이디
# 44. id_M 어머니 아이디
#
# 45. D_1_1 주관적 건강상태
#     1~5 : 매우좋음/좋음/보통/나쁨/매우나쁨
#     9 : 모름
#
# 46. D_2_1 최근2주간 몸이 불편했던 경험 유무
#     1 : 예 / 2 : 아니오
#     9 : 모름
#
# 47. D_2_wk 최근2주간 불편감일수
#     XX일
#     88 : 비해당 / 99 : 모름
#
# 48. DI1_dg 고혈압 의사진단 여부
#     0 : 없음 / 1 : 있음
#     8 : 비해당 / 9 : 모름
#
# 49. DI1_ag 고혈압 진단시기
#     0~79 세 / 80 : 80세이상
#     888 : 비해당 / 999 : 모름

# %%
# 컬럼 보기
pre_age18_1_column[ 40:50 ]
# Out:
# Index(['fam_rela', 'tins', 'npins', 'id_F', 'id_M', 'D_1_1', 'D_2_1', 'D_2_wk',
#        'DI1_dg', 'DI1_ag'],
#       dtype='object')

# %%
# 값 제거
for i in age18_1_column[ 40:50 ]:
    col_index = list(pre_age18_1.columns).index(i)

    # 88 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 88][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan
    
    # 99 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 99][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan

pre_age18_1.iloc[:, 40:50]
# Out:
#       fam_rela  tins  npins id_F  id_M  D_1_1  D_2_1  D_2_wk  DI1_dg  DI1_ag
# 0          6.0  20.0    2.0  NaN   NaN    3.0    2.0     NaN     1.0    75.0
# 1          1.0  10.0    1.0  NaN   NaN    1.0    2.0     NaN     0.0   888.0
# 2          2.0  10.0    1.0  NaN   NaN    3.0    2.0     NaN     1.0    74.0
# 3          1.0  20.0    2.0  NaN   NaN    1.0    2.0     NaN     0.0   888.0
# 4         10.0  30.0    2.0  NaN   NaN    3.0    2.0     NaN     1.0    69.0
# ...        ...   ...    ...  ...   ...    ...    ...     ...     ...     ...
# 1648       1.0  20.0    2.0  NaN   NaN    4.0    2.0     NaN     0.0   888.0
# 1649       2.0  20.0    2.0  NaN   NaN    4.0    1.0    14.0     0.0   888.0
# 1650       1.0  20.0    2.0  NaN   NaN    4.0    2.0     NaN     0.0   888.0
# 1651       6.0  20.0    2.0  NaN   NaN    4.0    2.0     NaN     0.0   888.0
# 1652       6.0  20.0    1.0  NaN   NaN    3.0    2.0     NaN     1.0    65.0
#
# [1653 rows x 10 columns]

# %%
# 값 제거
for i in age18_1_column[ 40:47 ]:
    col_index = list(pre_age18_1.columns).index(i)

    # 8 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 8][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan
    
    # 9 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 9][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan


pre_age18_1.iloc[:, 40:47]
# Out:
#       fam_rela  tins  npins id_F  id_M  D_1_1  D_2_1
# 0          6.0  20.0    2.0  NaN   NaN    3.0    2.0
# 1          1.0  10.0    1.0  NaN   NaN    1.0    2.0
# 2          2.0  10.0    1.0  NaN   NaN    3.0    2.0
# 3          1.0  20.0    2.0  NaN   NaN    1.0    2.0
# 4         10.0  30.0    2.0  NaN   NaN    3.0    2.0
# ...        ...   ...    ...  ...   ...    ...    ...
# 1648       1.0  20.0    2.0  NaN   NaN    4.0    2.0
# 1649       2.0  20.0    2.0  NaN   NaN    4.0    1.0
# 1650       1.0  20.0    2.0  NaN   NaN    4.0    2.0
# 1651       6.0  20.0    2.0  NaN   NaN    4.0    2.0
# 1652       6.0  20.0    1.0  NaN   NaN    3.0    2.0
#
# [1653 rows x 7 columns]

# %%
# 값 제거
for i in age18_1_column[ 48:50 ]:
    col_index = list(pre_age18_1.columns).index(i)

    # 8 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 8][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan
    
    # 9 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 9][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan


pre_age18_1.iloc[:, 48:50]
# Out:
#       DI1_dg  DI1_ag
# 0        1.0    75.0
# 1        0.0   888.0
# 2        1.0    74.0
# 3        0.0   888.0
# 4        1.0    69.0
# ...      ...     ...
# 1648     0.0   888.0
# 1649     0.0   888.0
# 1650     0.0   888.0
# 1651     0.0   888.0
# 1652     1.0    65.0
#
# [1653 rows x 2 columns]

# %%
# 값 제거
for i in age18_1_column[ 48:50 ]:
    col_index = list(pre_age18_1.columns).index(i)

    # 888 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 888][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan
    
    # 999 제거
    pre_age18_1_index = pre_age18_1[pre_age18_1[i] == 999][i].index

    for j in list(pre_age18_1_index):
        pre_age18_1.iloc[j,col_index] = np.nan


pre_age18_1.iloc[:, 48:50]
# Out:
#       DI1_dg  DI1_ag
# 0        1.0    75.0
# 1        0.0     NaN
# 2        1.0    74.0
# 3        0.0     NaN
# 4        1.0    69.0
# ...      ...     ...
# 1648     0.0     NaN
# 1649     0.0     NaN
# 1650     0.0     NaN
# 1651     0.0     NaN
# 1652     1.0    65.0
#
# [1653 rows x 2 columns]

# %% [markdown]
# ### column 50:60

# %% [markdown]
# 50. DI1_pt 고혈압 치료
#     8 : 비해당 / 9 : 모름
#
# 51. DI1_2 혈압조절제 복용
#     8 : 비해당 / 9 : 모름
#
# 52. DI2_dg 이상지질혈증 의사진단 여부
#     8 : 비해당 / 9 : 모름
#
# 53. DI2_ag 이상지질혈증 진단시기
#     0~80 나이
#     888 : 비해당 / 999 : 모름
#
# 54. DI2_pt 이상지질혈증 치료
#     8 : 비해당 / 9 : 모름
#
# 55. DI2_2 이상지질혈증 약복용
#     8 : 비해당 / 9 : 모름
#
# 56. DI3_dg 뇌졸중 의사진단여부
#     8 : 비해당 / 9 : 모름
#
# 57. DI3_ag 뇌졸중 진단시기
#     0~80 나이
#     888 : 비해당 / 999 : 모름
#
# 58. DI3_pt 뇌졸중 치료
#     8 : 비해당 / 9 : 모름
#
# 59.

# %%
# 컬럼 보기
pre_age18_1_column[ 50:60 ]
# Out:
# Index(['DI1_pt', 'DI1_2', 'DI2_dg', 'DI2_ag', 'DI2_pt', 'DI2_2', 'DI3_dg',
#        'DI3_ag', 'DI3_pt', 'DI3_2'],
#       dtype='object')

# %%
# 각 컬럼 유니크 값
for i in pre_age18_1_column[ 50:60 ]:
    print('-----------------'+i+'------------------')
    print(pre_age18_1[i].unique())
# Out:
# -----------------DI1_pt------------------
# [ 1.  8.  0. nan]
# -----------------DI1_2------------------
# [ 1.  8.  2.  5. nan  3.  4.]
# -----------------DI2_dg------------------
# [ 1.  0. nan  9.]
# -----------------DI2_ag------------------
# [ 75. 888.  59.  58.  71.  80.  64.  79.  65.  63.  nan  69.  60.  76.
#   66.  49.  57.  72.  55.  73.  74.  53.  56.  45.  61.  62.  51.  43.
#   50.  68.  70. 999.  42.  67.  77.  36.  78.  41.  54.  44.  40.  48.
#   25.  52.  37.  47.]
# -----------------DI2_pt------------------
# [ 1.  8.  0. nan  9.]
# -----------------DI2_2------------------
# [ 1.  8.  3.  5. nan  2.  9.  4.]
# -----------------DI3_dg------------------
# [ 1.  0. nan  9.]
# -----------------DI3_ag------------------
# [ 80. 888.  79.  nan 999.  58.  65.  73.  74.  75.  64.  68.  77.  43.
#   36.  63.  62.  76.  61.  69.  53.  57.  59.  38.  45.  42.  70.  72.
#   55.  60.  56.  67.  52.  71.  47.  50.  44.  51.]
# -----------------DI3_pt------------------
# ...

# %% [markdown]
# # 이동언 바보🤭

# %%
pre_age18_2
# Out:
#                  id  DI1_pr  DI2_pr  DI3_pr  DI4_pr  DI5_pr  DM2_pr  DM3_pr  \
# 0     b'A701020501'     1.0     1.0     0.0     NaN     NaN     NaN     NaN
# 1     b'A701021301'     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     b'A701021302'     1.0     NaN     NaN     NaN     NaN     1.0     NaN
# 3     b'A701023303'     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     b'A701023304'     1.0     NaN     NaN     NaN     NaN     NaN     1.0
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# 1648  b'R707025101'     NaN     NaN     NaN     1.0     NaN     NaN     NaN
# 1649  b'R707025102'     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# 1650  b'R707031101'     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# 1651  b'R708028503'     NaN     1.0     NaN     NaN     NaN     1.0     NaN
# 1652  b'R708028902'     1.0     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
pre_age18_1
# Out:
#               mod_d             id       ID_fam    year  region  town_t  \
# 0     b'2022.03.08'  b'A701020501'  b'A7010205'  2018.0     1.0     1.0
# 1     b'2022.03.08'  b'A701021301'  b'A7010213'  2018.0     1.0     1.0
# 2     b'2022.03.08'  b'A701021302'  b'A7010213'  2018.0     1.0     1.0
# 3     b'2022.03.08'  b'A701023303'  b'A7010233'  2018.0     1.0     1.0
# 4     b'2022.03.08'  b'A701023304'  b'A7010233'  2018.0     1.0     1.0
# ...             ...            ...          ...     ...     ...     ...
# 1648  b'2022.03.08'  b'R707025101'  b'R7070251'  2018.0     8.0     2.0
# 1649  b'2022.03.08'  b'R707025102'  b'R7070251'  2018.0     8.0     2.0
# 1650  b'2022.03.08'  b'R707031101'  b'R7070311'  2018.0     8.0     2.0
# 1651  b'2022.03.08'  b'R708028503'  b'R7080285'  2018.0     8.0     1.0
# 1652  b'2022.03.08'  b'R708028902'  b'R7080289'  2018.0     8.0     1.0
#
#       apt_t      psu  sex   age  ...  HEI_TVEG   HEI_VEG  HEI_PROTF  \
# ...
